# %% [markdown]
# # Introduction to Data Viz Using `ggplot2`

# %% [markdown]
# ### Data Viz
# - A combination of stats and art
# - Used in exploratory data analysis
#   - Generate hypotheses or confirm trends
# - Used to summarize key points
#   * Explain, inform or persuade

# %% [markdown]
# ### Data Viz - Cont'd
#
# * Why introduce it early?
#
#  * Graphics grammar requires practice
#    * Uses several unique concepts that will become second nature with practice
#
#  * Useful to illustrate examples throughout the course
#     * Most practicals will require some elementary viz
#  *

# %% [markdown]
# ### `ggplot2`
# * We will use ggplot2, the `defacto` plotting library in `R.`
#   * Instead of plotting I will use the term data viz.
#
#
#   * The function `qplot`, which we used previously relies on `ggplot` on the backend
# * `ggplot2` is the most popular package for data visualization with R.
#   * So clean that it has bindings in other languages
#     * Can be used in Python among other languages

# %% [markdown]
# * Part of `tidyverse`
#   * A collection of `R` packages designed for data science.
#   * The packages share an underlying design philosophy, grammar, and data structures.
#   * override and simplify many of the "objects" and functions in the standard `R` distribution.
#
# [https://www.tidyverse.org](https://www.tidyverse.org)
#
# ```R
# install.packages("tidyverse")
# library(tidyverse)
# ```

# %%
#check first if the library is not already installed
library(ggplot2)
# if you cannot import it, then run 
# install.packages("tidyverse")

# %%
ggplot(mpg) + 
    geom_point(mapping = aes(x = displ, y = hwy), size =5, color='red')
# Out:
# plot without title

# %%
ggplot(mpg) + 
   geom_point(mapping = aes(x = displ, y = hwy, size=class))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
ggplot(mpg) + geom_point(mapping = aes(x = class, y = hwy, size= factor(class)))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# ### `ggplot2` - Cont'd
#
# * ggplot2 describes the `g`rammar of `g`raphics for plots
#   * Provides a grammar (syntax?)  to build visualization
# * Hundreds of possible visualizations
#   * Dozens of registered extensions in the gallery to choose from.
#    [https://exts.ggplot2.tidyverse.org/gallery/](https://exts.ggplot2.tidyverse.org/gallery/)
# * In essence, a data viz is a set of layers
#   * A layer maps some aesthetics to variable(s)
# * Layers are combined to make publication-quality plots

# %%
ggplot()
# Out:
# plot without title

# %%
library(tidyverse)
data(mpg)
?mpg
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# A subset of the fuel economy data that the EPA makes available on <URL: https://fueleconomy.gov/>.
# It contains only models which had a new release every year between 1999 and 2008
#
# * Data frame (234 rows and 11)
#
#   * `manufacturer`: manufacturer name
#   * `model`: model name
#   * `displ`: engine displacement, in litres
#   * `year`: year of manufacture
#   * `cyl`: number of cylinders
#   * `trans`: type of transmission
#   * `drv`: the type of drive train, where f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#   * `cty`: city miles per gallon
#   * `hwy`: highway miles per gallon
#   * `fl`: fuel type
#   * `class`: "type" of car

# %%
str(mpg)
# Out:
# tibble [234 × 11] (S3: tbl_df/tbl/data.frame)
#  $ manufacturer: chr [1:234] "audi" "audi" "audi" "audi" ...
#  $ model       : chr [1:234] "a4" "a4" "a4" "a4" ...
#  $ displ       : num [1:234] 1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int [1:234] 1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int [1:234] 4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr [1:234] "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr [1:234] "f" "f" "f" "f" ...
#  $ cty         : int [1:234] 18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int [1:234] 29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr [1:234] "p" "p" "p" "p" ...
#  $ class       : chr [1:234] "compact" "compact" "compact" "compact" ...

# %%
ggplot(mpg) + geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
ggplot(mpg) + geom_point(mapping = aes(x = displ, y = hwy), size = 5)
# Out:
# plot without title

# %%
ggplot(data= mpg) +
    geom_point(mapping = aes(x = displ, y = hwy, ), color = "blue", size = 3)
# Out:
# plot without title

# %% [markdown]
# ### Fundamental Structure of `ggplot2` Expression
#
# ```R
# ggplot(data = <DATA>) +
#   <GEOM_FUNCTION>(mapping = aes(<MAPPINGS>))
# ```
#
# `<>` refers to values you need to define.

# %% [markdown]
# ### Fundamental Structure of `ggplot2` Expression - cont'd
#
# `ggplot()`:
#
#  * creates a coordinate system that you can add layers to.
#
#  * `ggplot2` comes with many `geom` functions that each add a different type of layer to a plot. E.g.:
#
#     * `geom_point`: scatter plots
# * `aes` stands for aesthetics (e.g.: size, the shape, or the color of your points)
#   * `aes` uses vector while `geom_point` param takes single values
# * Style can be modified using `params`

# %% [markdown]
# ### `GEOM_FUNCTION`
#
#  * A **geom** is the geometrical object that a plot uses to represent data.
#     * Visual object in this plot
#  * Plots types in ggplots2 different based on **geoms**.
#    * e.g.: `geom_point`, `geom_bar`, `geom_line`, `geom_boxplot`, etc.

# %% [markdown]
# ### `aes`
#
# * To map an aesthetic to a variable, associate the name of the aesthetic to the name of the variable inside `aes()`.
#   * ggplot2 will automatically assign a unique level of the aesthetic (here a unique color) to each unique value of the variable

# %%
# options(repr.plot.width = 8, repr.plot.height = 6)
ggplot(mpg) + geom_point(mapping = aes(x = displ, y = hwy, color=class), size = 5)
# Out:
# plot without title

# %%
mpg$class
# Out:
#   [1] "compact"    "compact"    "compact"    "compact"    "compact"
#   [6] "compact"    "compact"    "compact"    "compact"    "compact"
#  [11] "compact"    "compact"    "compact"    "compact"    "compact"
#  [16] "midsize"    "midsize"    "midsize"    "suv"        "suv"
#  [21] "suv"        "suv"        "suv"        "2seater"    "2seater"
#  [26] "2seater"    "2seater"    "2seater"    "suv"        "suv"
#  [31] "suv"        "suv"        "midsize"    "midsize"    "midsize"
#  [36] "midsize"    "midsize"    "minivan"    "minivan"    "minivan"
#  [41] "minivan"    "minivan"    "minivan"    "minivan"    "minivan"
#  [46] "minivan"    "minivan"    "minivan"    "pickup"     "pickup"
#  [51] "pickup"     "pickup"     "pickup"     "pickup"     "pickup"
#  [56] "pickup"     "pickup"     "suv"        "suv"        "suv"
#  [61] "suv"        "suv"        "suv"        "suv"        "pickup"
#  [66] "pickup"     "pickup"     "pickup"     "pickup"     "pickup"
# ...

# %%
# Question: why does the following throw a warning and color does not?
# more on how to fix this later

ggplot(mpg) + geom_point(mapping = aes(x = class, y = drv, size=class))
ggplot(mpg) + geom_point(mapping = aes(x = class, y = drv),  size=10)
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title
# plot without title

# %%
# Question: why does the following throw a warning and color does not?
# more on how to fix this later

ggplot(mpg) + geom_point(mapping = aes(x = class, y = drv, size=class))
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %% [markdown]
# # About Functions
# * A means to package some code to execute some functionality
#   * An algorithm
# * Typically:
#   * Takes one or more params
#   * Return something
#
# $$
# f(x,y) = x^2 + 3xy + \sqrt{y}
# $$
#
#
# * Remember defensive programming?
#   * stop()

# %%
add_one <- function(x){
  x+1
}

# %%
add_one(3)
# Out:
# [1] 4

# %%
add_one(10)
# Out:
# [1] 11

# %%
temp = 20
if (temp < 20){
  print("Cold")
}else{
  print("Warm")
}
# Out:
# [1] "Warm"

# %% [markdown]
# ### `if`/`else` Statements
#
# * `if/else` statements are integral parts of programming  languages
#   * Used in decision-making
# * if some test_expression is `TRUE`, then do something
# * otherwise do something else
#
# ```R
# if (test_expression){
#   # Do something here
# }else{
#   # Do something else
# }
# ```

# %%
temp = 30
if ( temp < 20){
  print("Cold")
}else if(temp >= 20 & temp < 30){
  print("pleasent")
}else{
  print("Wow!")
}
# Out:
# [1] "Wow!"

# %%
# Returns a numerical encoding for the car class

convert_class_int <- function(x) {
  if (x == "2seater") {
    1
  }else if (x == "compact"){
    2
  }else if (x == "subcompact"){
    3
  }else if(x == "midsize" ){
    4
  }else if(x == "midsize"){
    5
  }else if(x == "suv"){
    6
  }else if(x == "minivan"){
    7
  }else if(x == "pickup"){
    8
  }else{
    # Used for defensive programming purposes
    stop("value passed not recognized")
  }
}

# %%
# assertions used for testing (defensive programming purposes)
pickup_val <- convert_class_int("2seater")
assertthat::assert_that(pickup_val == 1)
# Out:
# [1] TRUE

# %%
pickup_val <- convert_class_int("pickup") 
assertthat::assert_that(pickup_val == 8)
# Out:
# [1] TRUE

# %%
# This is going to generate (raise an error)
convert_class_int("Something")
# Out:
# Error in convert_class_int("Something"): value passed not recognized
# Traceback:
#
# 1. convert_class_int("Something")
# 2. stop("value passed not recognized")   # at line 22 of file <text>

# %% [markdown]
# # Using the `sapply` Function
#
# * The `sapply` function is part of the apply() family
#   * A convenient and `s`implified way to apply a function to the elements of a vector
# * Gives each element of the vector to the function
#   * combines the returned values into a new list.

# %%
someData <- c(1,2,3,4,5)
power_3 <- function(x){
 x^3
}
processed_data = sapply(someData, power_3)
print(processed_data)
# Out:
# [1]   1   8  27  64 125

# %% [markdown]
# ### Using the `sapply` Function
#
# * Way to implement a data processing paradigm called `Split`-`Apply`- `Combine`
#   * Split: here, `sapply` splits the data into single elements
#   * Apply: we apply a function to each element of the data
#     * The input is passed in each iteration
#   * The data resulting from each function call is combined into a new vector of the same size as the origina

# %%
x = c(1, 2, 3, 4, 5)
names(x) = c("A", "B", "A", "A", "B")
print(x)
# Out:
# A B A A B
# 1 2 3 4 5

# %%
sapply(x, power_3)
# Out:
#   A   B   A   A   B
#   1   8  27  64 125

# %%
# using sapply Without USE.NAMES = FALSE
print(sapply(mpg$class, convert_class_int))
# Out:
#    compact    compact    compact    compact    compact    compact    compact
#          2          2          2          2          2          2          2
#    compact    compact    compact    compact    compact    compact    compact
#          2          2          2          2          2          2          2
#    compact    midsize    midsize    midsize        suv        suv        suv
#          2          4          4          4          6          6          6
#        suv        suv    2seater    2seater    2seater    2seater    2seater
#          6          6          1          1          1          1          1
#        suv        suv        suv        suv    midsize    midsize    midsize
#          6          6          6          6          4          4          4
#    midsize    midsize    minivan    minivan    minivan    minivan    minivan
#          4          4          7          7          7          7          7
# ...

# %%
mpg$class_numeric = sapply(mpg$class, convert_class_int, USE.NAMES = FALSE)

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact
#   class_numeric
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2

# %%
ggplot(mpg) + geom_point(aes(x = displ, y = hwy, size = class_numeric))
# Out:
# plot without title

# %% [markdown]
# ### `geom` params versus `aes`
# * All the params of `geom` can also be params of `aes`
# * `aes` mapping typically conveys information about the variable
#   * In `aes` it's a way to display a third dimension to the variable of sorts
# * In `geom`, the mapping is simply stylistic
# * You can combine mappings as long as they are not contradictory

# %%
# difference between the geom size and the aesthetic
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, size = class_numeric), size=5)
# Out:
# plot without title

# %%
# combine geom and aes parameters
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, alpha = class_numeric), size =10)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %%
# Add more than one mapping
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, size=class_numric, color=class_numric))
# Out:
# plot without title

# %%
mpg$displ < 5
# Out:
#   [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [13]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
#  [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE
#  [37]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [49]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE
#  [61]  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE
#  [73] FALSE FALSE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [85]  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [97]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [109]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [121]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE
# [133]  TRUE  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
# ...

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color=displ < 5))
# Out:
# plot without title

# %% [markdown]
# ### Uisng Facets
#
#  * Subplots of a larger plots
#    * Rach one contains a subset of points as described by a formula
#      * Forumula is a data structure not equation
#    * Points uniquely assigned to one of the subplots
#
#  *  `facet_wrap()`
#        *  formula: `~ varname`
#           * read as: `as a funciton of varname`
#        * More when we talk about modeling
#
#    * `facet_grid()`
#      * formula: two`varname_1 ~  varname_2`
#      * read as: using `varname_1` as a function of `varname2`

# %%
options(repr.plot.width = 20, repr.plot.height = 12)

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_wrap(~ class, nrow=2)
# Out:
# plot without title

# %%
options(repr.plot.width = 20, repr.plot.height = 12)

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
### ​Computed geoms (smooth geoms)

* Some `geoms` use `x` and `y` from data while others calculate new values to plot.
  * Those are called computed geoms
* For example
  * a smooth geom is going to compute a smooth line that represents the trend in the data
    * may exist for new x-values, so computes new x and y values
  * A histogram computes new bins (x values) and heights (y values) 
  * A boxplot may compute mean standard deviation
  * etc...

# %%
options(repr.plot.width = 14, repr.plot.height = 6)
ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
options(repr.plot.width = 14, repr.plot.height = 6)

ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy)) +
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
options(repr.plot.width = 14, repr.plot.height = 6)

ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy, linetype= drv), size=4)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ### mapping common `aes` to `ggplot`
# * You can pass a mapping to `ggplot()` insyead of each geom
#   * global mappings that apply to each geom in the graph.
#   * override things in each geom
# * local mappings for a specific layer are placed in the appropriate geom
# * overrides the global mappings for that layer only.

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(size=class_numeric)) +
  geom_smooth(aes()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
mpg_subcompact_subset = mpg[which(mpg$class=="subcompact"),]

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(color = class)) + 
  geom_smooth(data = mpg_subcompact_subset)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
  geom_point() + 
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
demo <- data.frame(freq=c( 1610, 4906, 12082, 13791, 21551 ), 
            cut=c("Fair", "Good", "Very Good","Premium", "Ideal"))
print(demo)
# Out:
#    freq       cut
# 1  1610      Fair
# 2  4906      Good
# 3 12082 Very Good
# 4 13791   Premium
# 5 21551     Ideal

# %%
options(repr.plot.width = 8, repr.plot.height = 6)
ggplot(data = demo) + 
  geom_bar(mapping = aes(x = cut, y = freq), stat = "identity")
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, y = stat(prop), group = 1))
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = cut))
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = clarity))
# Out:
# plot without title

# %% [markdown]
# ### Common Aesthetics
#
# `x`: x-axis values <br>
# `y`: y-axis values <br>
# `fill`: Fill color <br>
# `color`: color of points, outlines for other geoms <br>
# `size`: radius of points or thickness of lines <br>
# `alpha`: transparency <br>
# `linetype`: line dash pattern [see examples](https://ggplot2.tidyverse.org/reference/aes_linetype_size_shape.html) <br>
# `labels`: text on a plot or axes  <br>
# `shape`: shape [see examples] (https://ggplot2.tidyverse.org/reference/aes_linetype_size_shape.html) <br>

# %% [markdown]
# ### Questions
#
# * Complete the following Questions
# * Submit your Notebook to your Github account
# * DM me your username on Slack before leaving

# %% [markdown]
# **Question 1**
#
# * Provide at least two methods to view the number of of rows and the number of columsn in the `mpg` dataset

# %%
# Write your code here

print("using dim")
print(dim(mpg))
print("using nrow and ncol")
print(nrow(mpg))
print(ncol(mpg))
# Out:
# [1] "using dim"
# [1] 234  11
# [1] "using nrow and ncol"
# [1] 234
# [1] 11

# %% [markdown]
# **Question 2**
#
# * Run the following code:
# ```R
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = displ, y = hwy, color = "blue"))
# ```
# * What is wrong with the code.
# * Fix it so that the plot is displayed correctly.

# %%
# Write your code here

options(repr.plot.width = 18, repr.plot.height = 5)

library(gridExtra)

# Before fixing
plot_before <- ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = "blue"))
# After fixing
plot_after <- ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")


grid.arrange(plot_before, plot_after, ncol=2)
# Out:
# plot without title

# %% [markdown]
# **Question 3**
#
# * Change the code below so that mpg$class_numeric will be of type integer (int) rather than double (dbl)
# ```R
# mpg$class_numeric = sapply(mpg$class, convert_class_int, USE.NAMES = FALSE)
# ```
# * Inspect the result to make sure your solution worked

# %%
# Write your code here

convert_class_int <- function(x) {
  if (x == "2seater") {
    1
  }else if (x == "compact"){
    2
  }else if (x == "subcompact"){
    3
  }else if(x == "midsize" ){
    4
  }else if(x == "midsize"){
    5
  }else if(x == "suv"){
    6
  }else if(x == "minivan"){
    7
  }else if(x == "pickup"){
    8
  }else{
    # Used for defensive programming 
    stop("value passed not recognized")
  }
}

mpg$class_numeric = as.integer(sapply(mpg$class, convert_class_int))
str(mpg)
# Out:
# tibble [234 × 12] (S3: tbl_df/tbl/data.frame)
#  $ manufacturer : chr [1:234] "audi" "audi" "audi" "audi" ...
#  $ model        : chr [1:234] "a4" "a4" "a4" "a4" ...
#  $ displ        : num [1:234] 1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year         : int [1:234] 1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl          : int [1:234] 4 4 4 4 6 6 6 4 4 4 ...
#  $ trans        : chr [1:234] "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv          : chr [1:234] "f" "f" "f" "f" ...
#  $ cty          : int [1:234] 18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy          : int [1:234] 29 29 31 30 26 26 27 26 25 28 ...
#  $ fl           : chr [1:234] "p" "p" "p" "p" ...
#  $ class        : chr [1:234] "compact" "compact" "compact" "compact" ...
#  $ class_numeric: int [1:234] 2 2 2 2 2 2 2 2 2 2 ...

# %% [markdown]
# **Question 4**
#
# * Use a scatter plot to plot the variable `cty` (`x`-axis) and `hwy` (`y`-axis) of the `mpg` dataset
# * Add another geom that shows the liner regression between `x` and `y`
#   * The method for computing linear regression should be a linear model `lm` instead of the default (`loess`)
#   * Set the line color to `red`
#   * color the points by `class`
#   * set the points size to 6

# %%
options(repr.plot.width = 12, repr.plot.height = 8)

ggplot(mpg, aes(cty, hwy)) + 
 geom_point(aes(color=class), size=6) + 
 geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# **Question 5**
#
# * You noticed in the previous plot that there exist in the dataset subcompacts that has a city fuel consumption of 15 miles per gallon.
# * Extract the manufacturer and model of these subcompacts
#   * results should only have these columnsa

# %%
# Write your code here

mpg[which( (mpg$class == "subcompact") & (mpg$cty < 16)), c("manufacturer", "model")]
# Out:
#   manufacturer model
# 1 ford         mustang
# 2 ford         mustang
# 3 ford         mustang
# 4 ford         mustang
# 5 ford         mustang

# %% [markdown]
# **Question 6**
#
# * The following generates a warning
# ```R
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# ```
#
# * How can you fix that the code so all classes are displayed
# * Hint: you can manually specify your own values for the shapes to use using `scale_shape_manual` geom.  You can select any of the [following shapes](https://ggplot2.tidyverse.org/articles/ggplot2-specs_files/figure-html/unnamed-chunk-7-1.png)

# %%
# Write your code here
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy,shape = class)) + 
  scale_shape_manual(values = c(16,17,18,21,22,24,25))
# Out:
# plot without title

# %% [markdown]
# **Question 7**
#
# * Given the following two vectors
#
# ```R
# x <- c(3.385,0.48,1.35,465,36.33,27.66,14.83,1.04,4.19,0.425,0.101,0.92,1,0.005,0.06,3.5,2,1.7,2547,0.023,187.1,521,0.785,10,3.3,0.2,1.41,529,207,85,0.75,62,6654,3.5,6.8,35,4.05,0.12,0.023,0.01,1.4,250,2.5,55.5,100,52.16,10.55,0.55,60,3.6,4.288,0.28,0.075,0.122,0.048,192,3,160,0.9,1.62,0.104,4.235)
# y <- c(44.5,15.5,8.1,423,119.5,115,98.2,5.5,58,6.4,4,5.7,6.6,0.14,1,10.8,12.3,6.3,4603,0.3,419,655,3.5,115,25.6,5,17.5,680,406,325,12.3,1320,5712,3.9,179,56,17,1,0.4,0.25,12.5,490,12.1,175,157,440,179.5,2.4,81,21,39.2,1.9,1.2,3,0.33,180,25,169,2.6,11.4,2.5,50.4)
# ```
# * Combine the two vectors into a data frame called `sizeMass`
#   * Name the columns containing the vectors `x` and `y` as `size` and `mass` respectively
#
# * Use the code below to plot the data
#   * If you followed the above instructions the code should work without modification
#
# ```R
# ggplot(sizeMass, aes(size, mass)) +
#   geom_point() +
#   geom_smooth(method = "lm", color = "red", se = FALSE)
#
# ```

# %%
# Write your code here

x <- c(3.385,0.48,1.35,465,36.33,27.66,14.83,1.04,4.19,0.425,0.101,0.92,1,0.005,0.06,3.5,2,1.7,2547,0.023,187.1,521,0.785,10,3.3,0.2,1.41,529,207,85,0.75,62,6654,3.5,6.8,35,4.05,0.12,0.023,0.01,1.4,250,2.5,55.5,100,52.16,10.55,0.55,60,3.6,4.288,0.28,0.075,0.122,0.048,192,3,160,0.9,1.62,0.104,4.235)
y <- c(44.5,15.5,8.1,423,119.5,115,98.2,5.5,58,6.4,4,5.7,6.6,0.14,1,10.8,12.3,6.3,4603,0.3,419,655,3.5,115,25.6,5,17.5,680,406,325,12.3,1320,5712,3.9,179,56,17,1,0.4,0.25,12.5,490,12.1,175,157,440,179.5,2.4,81,21,39.2,1.9,1.2,3,0.33,180,25,169,2.6,11.4,2.5,50.4)
sizeMass <- data.frame(size=x, mass=y)

# Code as provided above
ggplot(sizeMass, aes(size, mass)) +
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# **Question 8**
#
# * In the above, the data is "squashed" because the data range varies substantially across observations. One way to fix this is by computing the log of the data. We will do that using two different approaches
#
# 1. add two new columns called them `size_log10` and `mass_log` that represent the log 10 values of the `size` and `mass` columns. Then, reuse the plotting code above by replacing `size` and `mass` with `size_log10` and `mass_log10` respectively
#   * Hint `log10()` can take as input a single value or a vector
#
# 2. Use the `scale_x_log10()` and `scale_y_log10()` to set different scales for the `x` and `y` aesthetics
#   * Simply add these transforms to the initial snippet of code prior to plotting `geom_point` or `geom_smooth`

# %%
# Write your code here (method 1 )

sizeMass$size_log10 <- log10(sizeMass$size)
sizeMass$mass_log10 <- log10(sizeMass$mass)
ggplot(sizeMass, aes(size_log10, mass_log10)) +
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
# Write your code here (method 2)

ggplot(sizeMass, aes(size, mass)) +
  geom_point() +
  scale_x_log10() +
  scale_y_log10() +

  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# Error in ggplot(sizeMass, aes(size, mass)): object 'sizeMass' not found
# Traceback:
#
# 1. ggplot(sizeMass, aes(size, mass))

# %% [markdown]
# **Submission Instructions**
#
#
# * Before you leave, submit your answers to your `Github` account
#   * Visit your repo page and make sure the changes were pushed correctly
# * Email me your `Slack` `username` once you've completed your work

# %%
class_ordinal  <-  factor(mpg$class, 
                     levels = c("2seater", "subcompact", "compact", "midsize", "minivan", "suv", "pickup"),
                    ordered=TRUE)

# %%
mpg$class_ordinal  <-  class_ordinal 

head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact
#   class_ordinal
# 1 compact
# 2 compact
# 3 compact
# 4 compact
# 5 compact
# 6 compact

# %%
ggplot(mpg) + geom_point(aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %%
ggplot(mpg) + 
  geom_point(aes(x = displ, y = hwy, color = class, ))
# Out:
# plot without title
