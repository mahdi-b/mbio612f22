# %%
library(tidyverse)
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
x = seq(1, 20, 0.05)

# %%
noise = rnorm(length(x), 0, 2)

# %%
y = 2 + 7*x + noise

# %%
data = data.frame(x, y)

# %%
ggplot(data)+
  geom_point(aes(x=x, y=y))
# Out:
# plot without title

# %%
model = lm(y~x, data)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.6054 -1.2948 -0.0579  1.3528  5.2654
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.93605    0.21754     8.9   <2e-16 ***
# x            7.00325    0.01835   381.6   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.97 on 379 degrees of freedom
# Multiple R-squared:  0.9974,	Adjusted R-squared:  0.9974
# F-statistic: 1.456e+05 on 1 and 379 DF,  p-value: < 2.2e-16
